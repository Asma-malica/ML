# %% [markdown]
# <a href="https://colab.research.google.com/github/Asma-malica/ML/blob/main/ML_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Linear Regression
#
# y=mx+c --->  m and c will be changed until finding the best fit called optimization
#
# L(de/dm) ---> change of m with respect to error/loss, L - learning rate to stablise the learning (shouldn't be less or more ,should be exact)
#
# #disadv:
# 1. L more --> missing of features
# 2. L less --> computation time high
#
# error detection --> mean square error (MSE)(for regression)
#
# MSE --> (sum(y_actual - y_predicted)^2) / len(data)
#
# residual error --> y_actual - y_predicted
#
# optimiser --> gradient descent
#
# epoch --> no of cycles
#
# #model:
#
# 1. epoch --> no of times model running
#
#   (model algo and error)
#
# #Optimisation:
#
# 1. E=(sum(y_actual - y_predicted)^2) / len(data)
#
# 2. dE/dm = d/dm (sum(y_actual - y_predicted)^2) / len(data)
#
# ---> substitute y_pred = mx + c
#
# 3. dE/dm = (-2x(sum(y-y'))) / n
#
# 4. dE/dc = (-2(sum(y-y'))) / n
#
# m = m - (L* dE/dm)
#
# c = c - (L* dE/dc)
#
# #Gradient Descent
#
# --> finding minimal error by decreasing the error with small steps by some means
#
# #Linear regression
#
# --> only works in linear data not for scattered
#
# 1. relationship between dependent and independent variable
#
# #polynomial regression
#
# --> applying linear regression for non linear data by applying n-th degree polynomial functions (or)
#
# --> converting polynomial/ non linear data to linear using degree (polynomial linear regression)
#
# degree - 1 --> linear polynomial regression (ax+b)
#
# degree - 2 --> quadratic regression (ax^2 + bx +c)
#
# degree - 3 --> cubic regression (ax^3 + bx^2 + cx)
#
# #hyperparameter
#
# hyper --> (the data we give to tune the model)
#
# parameter --> (data available to train the model)
#
# 1. degree of order (power)
#
#  selection of degree --> forward selection,backward selection (simply increasing, decreasing and finding)
#
# --> when degree is increased more higher --> overfitting (like mugup) training very good but testing is not good (fails)
#
# Loss --> error for single training example --> (y_actual - y_predicted)^2
#
# Cost --> avg error for total training set --> (sum(y_actual - y_predicted)^2) / len(data)
#
# variance --> difference from mean
#
# bias --> error
#
# bias high --> model trained with simple features only (underfitting) (lathorgical)
#
# 1. actual - pred (assumption high) may not give correct output
#
# variance --> calculating with complex features (overfitting) (mugup)
#
#  1. model learns too much from the data
#
# #must control bias and variance (Trade off)
#
# 1. optimal model (low bias, low variance)
#
# 2. underfitting (high bias , low variance)
#
# 3. overfitting (low bias, high variance)
#
# quadratic --> y= ax^2 + bx + c
#
# cubic --> y= ax^3 + bx^2 + cx + d
#
#
# #steps of polynomial reg
#
# data --> polynomial --> linear --> predict

# %% [markdown]
# #TensorFlow
#
# --> to control the flow of multi dimensional array
#
# #use of tensorflow:
# 1. no need to give the expression for the change in slopes manually
# 2. changing/ mutatation of slope related functions inbuilded
#
# Tensor --> array (immutable)
# variable --> mutable
# GradientTape --> to store all the slopes
#
# dy/dx=tape.gradient(y,x)
#
# --> m.assign_sub(dE/dm * L) ---> changing ans substituting m

# %% [markdown]
# #polynomial regresssion

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = np.array([2.1,3.8,6.5,9.2,11.3])

# %%
degree = 2

# %%
#design matrix # convert output to matrix
x_poly = np.column_stack([x**i for i in range(degree+1)])
x_poly
# Out:
# array([[ 1,  1,  1],
#        [ 1,  2,  4],
#        [ 1,  3,  9],
#        [ 1,  4, 16],
#        [ 1,  5, 25]])

# %%
weights = np.zeros(degree+1)
weights
# Out:
# array([0., 0., 0.])

# %%
learning_rate = 0.001

# %%
num_iteration = 10000

# %%
for _ in range(num_iteration):
  #calc predictions
  prediction = np.dot(x_poly, weights)
  #calc the error
  error = prediction - y
  #update the weights using gradient descent # to reduce cost function
  gradient = np.dot(x_poly.T,error) / len(x)
  weights -= learning_rate * gradient
  print(f"weights for iteration {_}: {weights}")
# Out:
# Streaming output truncated to the last 5000 lines.
# weights for iteration 5000: [0.54063445 1.51130733 0.1386439 ]
# weights for iteration 5001: [0.54061481 1.51132207 0.13864162]
# weights for iteration 5002: [0.54059517 1.51133681 0.13863933]
# weights for iteration 5003: [0.54057554 1.51135155 0.13863705]
# weights for iteration 5004: [0.5405559  1.51136629 0.13863476]
# weights for iteration 5005: [0.54053626 1.51138103 0.13863248]
# weights for iteration 5006: [0.54051662 1.51139577 0.13863019]
# weights for iteration 5007: [0.54049699 1.5114105  0.13862791]
# weights for iteration 5008: [0.54047735 1.51142524 0.13862563]
# weights for iteration 5009: [0.54045772 1.51143998 0.13862334]
# weights for iteration 5010: [0.54043808 1.51145472 0.13862106]
# weights for iteration 5011: [0.54041845 1.51146945 0.13861877]
# weights for iteration 5012: [0.54039882 1.51148419 0.13861649]
# weights for iteration 5013: [0.54037918 1.51149892 0.1386142 ]
# ...

# %%
def predict(x, weights):
  x_poly = np.array([x**i for i in range(degree+ 1)])
  return np.dot(x_poly, weights)

# %%
plt.scatter(x, y, label = " poly - reg")
x_range = np.linspace(min(x), max(x), 100)
y_pred = [predict(x, weights) for x in x_range]
plt.plot(x_range, y_pred,color="r", label="Poly-reg")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()
